# %%
import pandas as pd
movies = pd.read_csv(r"C:\Users\Nabeera\Downloads\IMDb movies - IMDb movies.csv")
# Out:
# C:\Users\Nabeera\AppData\Local\Temp\ipykernel_24936\3459171135.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies = pd.read_csv(r"C:\Users\Nabeera\Downloads\IMDb movies - IMDb movies.csv")

# %%
movies.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
# ...

# %%
movies = movies.drop_duplicates()

# %%
movies
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# ...

# %%
movies = movies.drop(['metascore', 'worlwide_gross_income'], axis=1)

# %%
movies.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  \
# ...

# %%
movies = movies.drop(['usa_gross_income', 'budget', 'production_company'], axis=1)

# %%
movies.head()
# Out:
#   imdb_title_id                        title  year                      genre  \
# 0     tt0000009                   Miss Jerry  1894                    Romance
# 1     tt0000574  The Story of the Kelly Gang  1906    Biography, Crime, Drama
# 2     tt0001892               Den sorte drøm  1911                      Drama
# 3     tt0002101                    Cleopatra  1912             Drama, History
# 4     tt0002130                    L'Inferno  1911  Adventure, Drama, Fantasy
#
#    duration language                             director  \
# 0        45                               Alexander Black
# 1        70                                  Charles Tait
# 2        53                                     Urban Gad
# 3       100  English                   Charles L. Gaskill
# 4        68  Italian  Francesco Bertolini, Adolfo Padovan
#
#                                          description  avg_vote  votes  \
# 0  The adventures of a female reporter in the 1890s.       5.9    154
# ...

# %%
movies_column_order = ['movie_id','title','year','Title_Year','cleanedTitle','genre','plot','ratings5','duration','language','director','description','avg_vote','votes','reviews_from_users','reviews_from_critics','rating']

# %%
movies_ordered = movies[movies_column_order]
movies_ordered.head()
# Out:
#    movie_id                        title  year  \
# 0         1                   Miss Jerry  1894
# 1         2  The Story of the Kelly Gang  1906
# 2         3               Den sorte drøm  1911
# 3         4                    Cleopatra  1912
# 4         5                    L'Inferno  1911
#
#                          Title_Year                 cleanedTitle  \
# 0                   Miss Jerry 1894                   Miss Jerry
# 1  The Story of the Kelly Gang 1906  The Story of the Kelly Gang
# 2                Den sorte drm 1911               Den sorte drøm
# 3                    Cleopatra 1912                    Cleopatra
# 4                     LInferno 1911                    L'Inferno
#
#                        genre  \
# 0                    Romance
# 1    Biography, Crime, Drama
# 2                      Drama
# 3             Drama, History
# 4  Adventure, Drama, Fantasy
#
#                                                 plot  ratings5  duration  \
# ...

# %%
movies_ordered
# Out:
#        movie_id                           title  year  \
# 0             1                      Miss Jerry  1894
# 1             2     The Story of the Kelly Gang  1906
# 2             3                  Den sorte drøm  1911
# 3             4                       Cleopatra  1912
# 4             5                       L'Inferno  1911
# ...         ...                             ...   ...
# 85850     85851                         Le lion  2020
# 85851     85852  De Beentjes van Sint-Hildegard  2020
# 85852     85853       Padmavyuhathile Abhimanyu  2019
# 85853     85854               Sokagin Çocuklari  2019
# 85854     85855      La vida sense la Sara Amat  2019
#
#                                Title_Year                    cleanedTitle  \
# 0                         Miss Jerry 1894                      Miss Jerry
# 1        The Story of the Kelly Gang 1906     The Story of the Kelly Gang
# 2                      Den sorte drm 1911                  Den sorte drøm
# ...

# %%
movies['cleanedTitle'] = movies["title"].str.replace('[^a-zA-Z0-9]', '')

# %%
movies['plot'] = movies["description"].apply(clean_text)

# %%
movies = movies.drop(['original_title', 'date_published', 'country','writer','actors'], axis=1)

# %%
movies['Title_Year'] = movies['cleanedTitle'] + ' (' + movies['year'].astype(str) + ')'

# %%
import re

def clean_text(text):
    text = re.sub("[^a-zA-Z0-9 ]", "", text)
    return text
movies['Title_Year'] = movies["Title_Year"].apply(clean_text)

# %%
movies = movies.fillna('')

# %%
movies = movies.fillna('')

# %%
import numpy as np

# %%
movies['rating'] = movies['avg_vote'].apply(lambda x: int(np.floor(x)))

# %%
movies['ratings5'] = (movies['avg_vote']/2).apply(lambda x: int(round(x)))

# %%
reviews = pd.read_csv(r"C:\Users\Nabeera\Downloads\ml-25m\ml-25m\ratings.csv")
reviews.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %%
reviews
# Out:
#           userId  movieId  rating   timestamp
# 0              1      296     5.0  1147880044
# 1              1      306     3.5  1147868817
# 2              1      307     5.0  1147868828
# 3              1      665     5.0  1147878820
# 4              1      899     3.5  1147868510
# ...          ...      ...     ...         ...
# 25000090  162541    50872     4.5  1240953372
# 25000091  162541    55768     2.5  1240951998
# 25000092  162541    56176     2.0  1240950697
# 25000093  162541    58559     4.0  1240953434
# 25000094  162541    63876     5.0  1240952515
#
# [25000095 rows x 4 columns]

# %%
movies['movie_id'] = range(1, len(movies) + 1)

# %%
reviews = reviews[reviews['movieId'] <= 85855]

# %%
reviews
# Out:
#           userId  movieId  rating   timestamp
# 0              1      296     5.0  1147880044
# 1              1      306     3.5  1147868817
# 2              1      307     5.0  1147868828
# 3              1      665     5.0  1147878820
# 4              1      899     3.5  1147868510
# ...          ...      ...     ...         ...
# 25000090  162541    50872     4.5  1240953372
# 25000091  162541    55768     2.5  1240951998
# 25000092  162541    56176     2.0  1240950697
# 25000093  162541    58559     4.0  1240953434
# 25000094  162541    63876     5.0  1240952515
#
# [22623091 rows x 4 columns]

# %%
reviewsl= reviews

# %%
reviewsl
# Out:
#           userId  movieId  rating   timestamp  rating5
# 0              1      296       5  1147880044        5
# 1              1      306       4  1147868817        4
# 2              1      307       5  1147868828        5
# 3              1      665       5  1147878820        5
# 4              1      899       4  1147868510        4
# ...          ...      ...     ...         ...      ...
# 25000090  162541    50872       4  1240953372        4
# 25000091  162541    55768       2  1240951998        2
# 25000092  162541    56176       2  1240950697        2
# 25000093  162541    58559       4  1240953434        4
# 25000094  162541    63876       5  1240952515        5
#
# [22623091 rows x 5 columns]

# %%
reviewsl['rating'] = reviewsl['rating'].apply(lambda x: int(round(x)))
# Out:
# C:\Users\Nabeera\AppData\Local\Temp\ipykernel_24936\3343935441.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviewsl['rating'] = reviewsl['rating'].apply(lambda x: int(round(x)))

# %%
reviews['rating5'] = reviews['rating'].apply(lambda x: int(round(x)))
# Out:
# C:\Users\Nabeera\AppData\Local\Temp\ipykernel_24936\1262657856.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews['rating5'] = reviews['rating'].apply(lambda x: int(round(x)))

# %%
reviews.loc[:, 'rating5'] = reviews['rating'].apply(lambda x: int(round(x)))

# %%
reviews
# Out:
#           userId  movieId  rating   timestamp  rating5
# 0              1      296       5  1147880044        5
# 1              1      306       4  1147868817        4
# 2              1      307       5  1147868828        5
# 3              1      665       5  1147878820        5
# 4              1      899       4  1147868510        4
# ...          ...      ...     ...         ...      ...
# 25000090  162541    50872       4  1240953372        4
# 25000091  162541    55768       2  1240951998        2
# 25000092  162541    56176       2  1240950697        2
# 25000093  162541    58559       4  1240953434        4
# 25000094  162541    63876       5  1240952515        5
#
# [22623091 rows x 5 columns]

# %%
reviews.to_csv('movie_reviews.csv', index=False)

# %%
reviews['review_id'] = range(1, len(reviews) + 1)
reviews
# Out:
# C:\Users\Nabeera\AppData\Local\Temp\ipykernel_24936\4154865430.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews['review_id'] = range(1, len(reviews) + 1)
#           userId  movieId  rating   timestamp  rating5  review_id
# 0              1      296       5  1147880044        5          1
# 1              1      306       4  1147868817        4          2
# 2              1      307       5  1147868828        5          3
# 3              1      665       5  1147878820        5          4
# 4              1      899       4  1147868510        4          5
# ...          ...      ...     ...         ...      ...        ...
# 25000090  162541    50872       4  1240953372        4   22623087
# ...

# %%
movies.to_csv('movie_dataset.csv', index=False)
